# %%
import sys
import os
import pandas as pd

current_dir = os.path.abspath(os.getcwd())
parent_dir = os.path.dirname(current_dir)
sys.path.append(os.path.join(parent_dir, 'Scripts'))

import data_acquisition
import Data_collection

# %%
data_acquisition.collect_data(start=2017, end= 2024)
# Out:
# file_path
# fetching data for 2017_2018 ..
# Fetching game data for 2017-2018 Season:   0%|          | 0/1376 [00:00<?, ?it/s]
# Fetching game data for 2017-2018 Season: 100%|██████████| 1376/1376 [01:31<00:00, 14.99it/s]
# saving data for 2017_2018 ..
# file_path
# fetching data for 2018_2019 ..
# Fetching game data for 2018-2019 Season: 100%|██████████| 1376/1376 [01:21<00:00, 16.90it/s]
# saving data for 2018_2019 ..
# file_path
# fetching data for 2019_2020 ..
# Fetching game data for 2019-2020 Season: 100%|██████████| 1376/1376 [01:19<00:00, 17.22it/s]
# saving data for 2019_2020 ..
# file_path
# fetching data for 2020_2021 ..
# Fetching game data for 2020-2021 Season: 100%|██████████| 1376/1376 [01:20<00:00, 17.15it/s]
# saving data for 2020_2021 ..
# file_path
# fetching data for 2021_2022 ..
# Fetching game data for 2021-2022 Season: 100%|██████████| 1376/1376 [01:24<00:00, 16.35it/s]
# saving data for 2021_2022 ..
# file_path
# fetching data for 2022_2023 ..
# Fetching game data for 2022-2023 Season: 100%|██████████| 1376/1376 [01:26<00:00, 15.92it/s]
# saving data for 2022_2023 ..
# file_path
# fetching data for 2023_2024 ..
# Fetching game data for 2023-2024 Season: 100%|██████████| 1376/1376 [01:50<00:00, 12.50it/s]
# saving data for 2023_2024 ..

# %%
## environ 2 minutes
base_path = '../data/raw/'
df = Data_collection.load_all_seasons(base_path)
# Out:
# Seasons: 100%|██████████| 7/7 [01:54<00:00, 16.33s/it]

# %%
df
# Out:
#                                                           2017020001  \
# id                                                        2017020001
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-04
# venue                                  {'default': 'Bell MTS Place'}
# venueLocation                                {'default': 'Winnipeg'}
# startTimeUTC                                    2017-10-04T23:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -05:00
# tvBroadcasts       [{'id': 282, 'market': 'N', 'countryCode': 'CA...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 10, 'commonName': {'default': 'Maple Le...
# homeTeam           {'id': 52, 'commonName': {'default': 'Jets'}, ...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 10, 'playerId': 8466139, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020002  \
# id                                                        2017020002
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-04
# venue                                {'default': 'PPG Paints Arena'}
# venueLocation                              {'default': 'Pittsburgh'}
# startTimeUTC                                    2017-10-05T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 241, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 4, 'periodType': 'OT', 'maxRegulati...
# awayTeam           {'id': 19, 'commonName': {'default': 'Blues'},...
# homeTeam           {'id': 5, 'commonName': {'default': 'Penguins'...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                 {'lastPeriodType': 'OT', 'otPeriods': 1}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 19, 'playerId': 8469501, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020003  \
# id                                                        2017020003
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-04
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2017-10-05T02:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 282, 'market': 'N', 'countryCode': 'CA...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 20, 'commonName': {'default': 'Flames'}...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 20, 'playerId': 8469608, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020004  \
# id                                                        2017020004
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-04
# venue                          {'default': 'SAP Center at San Jose'}
# venueLocation                                {'default': 'San Jose'}
# startTimeUTC                                    2017-10-05T02:30:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -07:00
# tvBroadcasts       [{'id': 241, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 4, 'commonName': {'default': 'Flyers'},...
# homeTeam           {'id': 28, 'commonName': {'default': 'Sharks'}...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 56, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 28, 'playerId': 8466138, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020005  \
# id                                                        2017020005
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-05
# venue                                       {'default': 'TD Garden'}
# venueLocation                                  {'default': 'Boston'}
# startTimeUTC                                    2017-10-05T23:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 141, 'market': 'A', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 18, 'commonName': {'default': 'Predator...
# homeTeam           {'id': 6, 'commonName': {'default': 'Bruins'},...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 6, 'playerId': 8465009, 'firstName...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020006  \
# id                                                        2017020006
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-05
# venue                                  {'default': 'KeyBank Center'}
# venueLocation                                 {'default': 'Buffalo'}
# startTimeUTC                                    2017-10-05T23:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 131, 'market': 'A', 'countryCode': 'CA...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 5, 'periodType': 'SO', 'maxRegulati...
# awayTeam           {'id': 8, 'commonName': {'default': 'Canadiens...
# homeTeam           {'id': 7, 'commonName': {'default': 'Sabres'},...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                 {'lastPeriodType': 'SO'}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 8, 'playerId': 8468309, 'firstName...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020007  \
# id                                                        2017020007
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-05
# venue                           {'default': 'Madison Square Garden'}
# venueLocation                                {'default': 'New York'}
# startTimeUTC                                    2017-10-05T23:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 2, 'market': 'A', 'countryCode': 'US',...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 21, 'commonName': {'default': 'Avalanch...
# homeTeam           {'id': 3, 'commonName': {'default': 'Rangers'}...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 101, 'periodDescriptor': {'number...
# rosterSpots        [{'teamId': 3, 'playerId': 8468685, 'firstName...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020008  \
# id                                                        2017020008
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-05
# venue                            {'default': 'Canadian Tire Centre'}
# venueLocation                                  {'default': 'Ottawa'}
# startTimeUTC                                    2017-10-05T23:30:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 230, 'market': 'H', 'countryCode': 'CA...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 5, 'periodType': 'SO', 'maxRegulati...
# awayTeam           {'id': 15, 'commonName': {'default': 'Capitals...
# homeTeam           {'id': 9, 'commonName': {'default': 'Senators'...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                 {'lastPeriodType': 'SO'}
# plays              [{'eventId': 8, 'periodDescriptor': {'number':...
# rosterSpots        [{'teamId': 9, 'playerId': 8467950, 'firstName...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020009  \
# id                                                        2017020009
# season                                                      20172018
# gameType                                                           2
# limitedScoring                                                 False
# gameDate                                                  2017-10-05
# venue                            {'default': 'Little Caesars Arena'}
# venueLocation                                 {'default': 'Detroit'}
# startTimeUTC                                    2017-10-05T23:30:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 241, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 30, 'commonName': {'default': 'Wild'}, ...
# homeTeam           {'id': 17, 'commonName': {'default': 'Red Wing...
# shootoutInUse                                                   True
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                         5
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 51, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 30, 'playerId': 8464989, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2017020010  ...  \
# id                                                        2017020010  ...
# season                                                      20172018  ...
# gameType                                                           2  ...
# limitedScoring                                                 False  ...
# gameDate                                                  2017-10-05  ...
# venue                                   {'default': 'United Center'}  ...
# venueLocation                                 {'default': 'Chicago'}  ...
# startTimeUTC                                    2017-10-06T00:30:00Z  ...
# easternUTCOffset                                              -04:00  ...
# venueUTCOffset                                                -05:00  ...
# tvBroadcasts       [{'id': 284, 'market': 'N', 'countryCode': 'CA...  ...
# gameState                                                        OFF  ...
# gameScheduleState                                                 OK  ...
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...  ...
# awayTeam           {'id': 5, 'commonName': {'default': 'Penguins'...  ...
# homeTeam           {'id': 16, 'commonName': {'default': 'Blackhaw...  ...
# shootoutInUse                                                   True  ...
# otInUse                                                         True  ...
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...  ...
# displayPeriod                                                      1  ...
# maxPeriods                                                         5  ...
# gameOutcome                                {'lastPeriodType': 'REG'}  ...
# plays              [{'eventId': 5, 'periodDescriptor': {'number':...  ...
# rosterSpots        [{'teamId': 16, 'playerId': 8469544, 'firstNam...  ...
# regPeriods                                                         3  ...
# summary                                                           {}  ...
# specialEvent                                                     NaN  ...
#
#                                                           2023030324  \
# id                                                        2023030324
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-05-29
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2024-05-30T00:30:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 385, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 25, 'commonName': {'default': 'Stars'},...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 25, 'playerId': 8470600, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030325  \
# id                                                        2023030325
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-05-31
# venue                        {'default': 'American Airlines Center'}
# venueLocation                                  {'default': 'Dallas'}
# startTimeUTC                                    2024-06-01T00:30:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -05:00
# tvBroadcasts       [{'id': 385, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# homeTeam           {'id': 25, 'commonName': {'default': 'Stars'},...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 25, 'playerId': 8470600, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030326  \
# id                                                        2023030326
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-02
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2024-06-03T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 385, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 25, 'commonName': {'default': 'Stars'},...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 25, 'playerId': 8470600, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030411  \
# id                                                        2023030411
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-08
# venue                              {'default': 'Amerant Bank Arena'}
# venueLocation                                 {'default': 'Sunrise'}
# startTimeUTC                                    2024-06-09T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# homeTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 102, 'periodDescriptor': {'number...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030412  \
# id                                                        2023030412
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-10
# venue                              {'default': 'Amerant Bank Arena'}
# venueLocation                                 {'default': 'Sunrise'}
# startTimeUTC                                    2024-06-11T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# homeTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 13, 'playerId': 8473449, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030413  \
# id                                                        2023030413
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-13
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2024-06-14T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 102, 'periodDescriptor': {'number...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030414  \
# id                                                        2023030414
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-15
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2024-06-16T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030415  \
# id                                                        2023030415
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-18
# venue                              {'default': 'Amerant Bank Arena'}
# venueLocation                                 {'default': 'Sunrise'}
# startTimeUTC                                    2024-06-19T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# homeTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 102, 'periodDescriptor': {'number...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030416  \
# id                                                        2023030416
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-21
# venue                                    {'default': 'Rogers Place'}
# venueLocation                                {'default': 'Edmonton'}
# startTimeUTC                                    2024-06-22T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -06:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# homeTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 52, 'periodDescriptor': {'number'...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
#                                                           2023030417
# id                                                        2023030417
# season                                                      20232024
# gameType                                                           3
# limitedScoring                                                 False
# gameDate                                                  2024-06-24
# venue                              {'default': 'Amerant Bank Arena'}
# venueLocation                                 {'default': 'Sunrise'}
# startTimeUTC                                    2024-06-25T00:00:00Z
# easternUTCOffset                                              -04:00
# venueUTCOffset                                                -04:00
# tvBroadcasts       [{'id': 384, 'market': 'N', 'countryCode': 'US...
# gameState                                                        OFF
# gameScheduleState                                                 OK
# periodDescriptor   {'number': 3, 'periodType': 'REG', 'maxRegulat...
# awayTeam           {'id': 22, 'commonName': {'default': 'Oilers'}...
# homeTeam           {'id': 13, 'commonName': {'default': 'Panthers...
# shootoutInUse                                                  False
# otInUse                                                         True
# clock              {'timeRemaining': '00:00', 'secondsRemaining':...
# displayPeriod                                                      1
# maxPeriods                                                       NaN
# gameOutcome                                {'lastPeriodType': 'REG'}
# plays              [{'eventId': 102, 'periodDescriptor': {'number...
# rosterSpots        [{'teamId': 22, 'playerId': 8470621, 'firstNam...
# regPeriods                                                         3
# summary                                                           {}
# specialEvent                                                     NaN
#
# [27 rows x 8911 columns]

# %%
Data = Data_collection.transformEventData(df)

# %%
Data
# Out:
#             gameId  evt_idx  prd prdTime         team coord_x coord_y  \
# 0       2017020001       54    1   00:38         Jets     -36     -28
# 1       2017020001       55    1   00:49         Jets     -75       1
# 2       2017020001       58    1   01:03         Jets     -73      10
# 3       2017020001       62    1   01:46  Maple Leafs      80      -3
# 4       2017020001       68    1   03:42         Jets     -44     -21
# ...            ...      ...  ...     ...          ...     ...     ...
# 559626  2023030417      252    3   12:57       Oilers      85       1
# 559627  2023030417     1183    3   14:25     Panthers     -53     -27
# 559628  2023030417     1189    3   15:23     Panthers     -59     -29
# 559629  2023030417     1193    3   15:48       Oilers      57     -26
# 559630  2023030417     1215    3   17:42       Oilers      85       4
#
#        shotCategory  goalFlag   shotBy  ...       visitorTeam       hostTeam  \
# 0             wrist     False  8477504  ...  Maple Leafs, TOR      Jets, WPG
# 1             wrist     False  8473574  ...  Maple Leafs, TOR      Jets, WPG
# 2          backhand     False  8473412  ...  Maple Leafs, TOR      Jets, WPG
# 3             wrist     False  8470611  ...  Maple Leafs, TOR      Jets, WPG
# 4              snap     False  8479339  ...  Maple Leafs, TOR      Jets, WPG
# ...             ...       ...      ...  ...               ...            ...
# 559626         poke     False  8475786  ...       Oilers, EDM  Panthers, FLA
# 559627        wrist     False  8475765  ...       Oilers, EDM  Panthers, FLA
# 559628         snap     False  8477493  ...       Oilers, EDM  Panthers, FLA
# 559629        wrist     False  8477498  ...       Oilers, EDM  Panthers, FLA
# 559630        wrist     False  8475218  ...       Oilers, EDM  Panthers, FLA
#
#        homeRinkSide awayRinkSide game_seconds shot_distance  shot_angle  \
# 0              left        right           38     59.941638   27.847578
# 1              left        right           49     14.035669   -4.085617
# 2              left        right           63     18.867962  -32.005383
# 3              left        right          106      9.486833   18.434949
# 4              left        right          222     49.658836   25.016893
# ...             ...          ...          ...           ...         ...
# 559626         left        right          777      4.123106  -14.036243
# 559627         left        right          865          45.0   36.869898
# 559628         left        right          923     41.725292   44.028978
# 559629         left        right          948     41.231056   39.093859
# 559630         left        right         1062      5.656854       -45.0
#
#         rebond  changement_angle_tir    vitesse
# 0        False                     0   3.507600
# 1        False                     0   5.457220
# 2        False                     0  13.017083
# 3        False                     0   3.681520
# 4        False                     0   0.603202
# ...        ...                   ...        ...
# 559626    True            -25.346176   6.082763
# 559627   False                     0   1.756665
# 559628   False                     0  27.459060
# 559629   False                     0   5.481021
# 559630   False                     0   0.000000
#
# [559631 rows x 29 columns]
